# %% [markdown]
# # Verify the AgentScope installation
#
# Run this notebook after creating and activating the lesson virtual environment. It makes no model request.

# %%
import sys

import agentscope

if sys.version_info < (3, 10):
    raise RuntimeError("AgentScope requires Python 3.10 or newer.")

print(f"Python: {sys.version.split()[0]}")
print(f"AgentScope: {agentscope.__version__}")
print("Installation check passed.")
