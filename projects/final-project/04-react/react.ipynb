# %% [markdown]
# # ReAct Pattern
#
# Implement an iterative reasoning, action, and observation loop separate from Planning. Store project-specific inputs in `data/`.

# %%
# Add framework setup, ReAct loop, test cases, and evaluation code here.
