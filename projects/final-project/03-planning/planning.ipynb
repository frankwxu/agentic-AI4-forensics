# %% [markdown]
# # Planning Pattern
#
# Implement explicit planning, execution, observation recording, and replanning. Store project-specific inputs in `data/`.

# %%
# Add framework setup, plan/replan logic, test cases, and evaluation code here.
