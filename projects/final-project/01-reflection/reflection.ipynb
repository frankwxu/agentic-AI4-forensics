# %% [markdown]
# # Reflection Pattern
#
# Implement an initial response, structured critique, and evidence-based revision. Store project-specific inputs in `data/`.

# %%
# Add framework setup, prompts, test cases, and evaluation code here.
