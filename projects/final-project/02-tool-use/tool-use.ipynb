# %% [markdown]
# # Tool Use Pattern
#
# Implement an agent that selects and calls one or more tools. Store project-specific inputs in `data/`.

# %%
# Add framework setup, tool schemas, test cases, and evaluation code here.
