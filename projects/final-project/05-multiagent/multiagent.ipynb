# %% [markdown]
# # Multiagent Pattern
#
# Implement coordination among at least two agents with distinct roles. Store project-specific inputs in `data/`.

# %%
# Add framework setup, agent roles, coordination logic, test cases, and evaluation code here.
